# %% [markdown]
# ## Face Recognition
#
# Identificar a Sergio y a otras muchas personas
#
# https://machinelearningmastery.com/how-to-perform-face-recognition-with-vggface2-convolutional-neural-network-in-keras/

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from tensorflow.python.keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,ZeroPadding2D,Dropout,Softmax
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.python.keras import Sequential
from sklearn.datasets import fetch_lfw_people
from sklearn.datasets import fetch_lfw_pairs
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import cv2
# !pip install scikit-plot
import scikitplot as skplt
import numpy as np
import random
import pandas as pd

# Commented out IPython magic to ensure Python compatibility.
import tensorflow_datasets as tfds
import tensorflow as tf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-plot in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.10.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %% [markdown]
# ## Prepare Training
#
# El dataset contiene imágenes de 19 personas, no obstante para cada una de ellas hay un número de imágenes diferente. Se escogen solo las personas que tengan 100 imágenes o más.

# %%
# For GOOGLE COLAB
# ==========
from google.colab import drive
drive.mount("/content/drive", force_remount = True)
data_dir = "/content/drive/MyDrive/Colab Notebooks/scikit_learn_data2"
# Out:
# Mounted at /content/drive

# %%
# For OS
# ==========

"""
import os
d = os.path.dirname(os.getcwd())
data_zip_dir = os.path.join(d, "data/model_4/scikit_learn_data.zip")
import zipfile
with zipfile.ZipFile(data_zip_dir, 'r') as zip_ref:
   zip_ref.extractall(os.path.join(d, "data/model_4"))

data_dir = os.path.join(d, "data/model_4/scikit_learn_data2")
"""
# Out:
# '\nimport os\nd = os.path.dirname(os.getcwd())\ndata_zip_dir = os.path.join(d, "data/model_4/scikit_learn_data.zip")\nimport zipfile\nwith zipfile.ZipFile(data_zip_dir, \'r\') as zip_ref:\n   zip_ref.extractall(os.path.join(d, "data/model_4"))\n\ndata_dir = os.path.join(d, "data/model_4/scikit_learn_data2")\n'

# %%
#data = fetch_lfw_people(data_home = data_dir, resize=1.0, color=True)
data = fetch_lfw_people(data_home = data_dir, min_faces_per_person = 387, resize = 1.0, slice_ = (slice(30, 220), slice(30, 220)), color = True, funneled = True)

class_count = len(data.target_names)

# %%
print(class_count)
# Out:
# 2

# %%
from collections import Counter
counts = Counter(data.target)
names = {}

for key in counts.keys():
    names[data.target_names[key]] = counts[key]

df = pd.DataFrame.from_dict(names, orient = 'index')
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
# %matplotlib inline
import seaborn as sns
sns.set()

fig, ax = plt.subplots(3, 6, figsize = (18, 10))

for i, axi in enumerate(ax.flat):
    axi.imshow(data.images[i], cmap = plt.cm.gray_r, vmin = 0, vmax = 16)
    axi.set(xticks = [], yticks=[], xlabel = data.target_names[data.target[i]])

# %% [markdown]
# ## Balancing the data
#
# Los modelos de clasificación se entrenan mejor con datasets que estén balanceados. Es por ello que se utilizan 387 imágenes para cada persona.

# %%
mask = np.zeros(data.target.shape, dtype=np.bool_)

for target in np.unique(data.target):
    mask[np.where(data.target == target)[0][:387]] = 1

x_faces = data.data[mask]
y_faces = data.target[mask]
x_faces = np.reshape(x_faces, (x_faces.shape[0], data.images.shape[1], data.images.shape[2], data.images.shape[3]))
x_faces.shape
# Out:
# (774, 190, 190, 3)

# %%
####### Train and test splitting of data #######

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.model_selection import train_test_split

face_images = preprocess_input(np.array(x_faces))
face_labels = to_categorical(y_faces)

# In the first step we will split the data in training and remaining dataset
x_train, x_rem, y_train, y_rem = train_test_split(face_images, face_labels, train_size = 0.7, stratify = face_labels, random_state = 0)

# Now since we want the valid and test size to be equal (15% each of overall data). 
# Define valid_size=0.5 (that is 50% of remaining data)
x_valid, x_test, y_valid, y_test = train_test_split(x_rem, y_rem, test_size = 0.5, stratify = y_rem, random_state = 0)

print("Train: ", x_train.shape)
print("Validation: ", x_valid.shape)
print("Test: ", x_test.shape)
# Out:
# Train:  (541, 190, 190, 3)
# Validation:  (116, 190, 190, 3)
# Test:  (117, 190, 190, 3)

# %% [markdown]
# ## Use transfer learning with ResNet50 and ImageNet weights
#
# El primer modelo emplea transfer learning con ResNet50 con pesos calculados de una red entranada con más de 1 millón de imágenes del dataset de ImageNet. Se empieza por cargar ResNet50 sin las capas de clasificación y congelando las capas del cuello de botella

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(weights='imagenet', include_top=False)
base_model.trainable = False

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Resizing

model = Sequential()
model.add(Resizing(224, 224))
model.add(base_model)
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(class_count, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['categorical_accuracy'])

# %%
import time

start_time = time.time()
hist = model.fit(x_train, y_train, validation_data = (x_valid, y_valid), batch_size = 100, epochs = 50)
end_time = time.time()

print("###### Total Time Taken: ", round((end_time - start_time)/60), 'Minutes ######')
# Out:
# Epoch 1/50
# 6/6 [==============================] - 26s 1s/step - loss: 16.4707 - categorical_accuracy: 0.5009 - val_loss: 4.3844 - val_categorical_accuracy: 0.5000
# Epoch 2/50
# 6/6 [==============================] - 3s 450ms/step - loss: 3.1346 - categorical_accuracy: 0.5323 - val_loss: 1.1750 - val_categorical_accuracy: 0.5000
# Epoch 3/50
# 6/6 [==============================] - 3s 482ms/step - loss: 1.7029 - categorical_accuracy: 0.4972 - val_loss: 1.7169 - val_categorical_accuracy: 0.8448
# Epoch 4/50
# 6/6 [==============================] - 3s 444ms/step - loss: 1.3172 - categorical_accuracy: 0.6654 - val_loss: 1.0115 - val_categorical_accuracy: 0.5000
# Epoch 5/50
# 6/6 [==============================] - 3s 466ms/step - loss: 0.7881 - categorical_accuracy: 0.5878 - val_loss: 0.6985 - val_categorical_accuracy: 0.9828
# Epoch 6/50
# 6/6 [==============================] - 3s 463ms/step - loss: 0.7163 - categorical_accuracy: 0.8429 - val_loss: 0.6856 - val_categorical_accuracy: 0.5086
# Epoch 7/50
# 6/6 [==============================] - 3s 448ms/step - loss: 0.5985 - categorical_accuracy: 0.7726 - val_loss: 0.5316 - val_categorical_accuracy: 0.9828
# Epoch 8/50
# 6/6 [==============================] - 3s 456ms/step - loss: 0.5438 - categorical_accuracy: 0.9187 - val_loss: 0.5110 - val_categorical_accuracy: 0.8276
# Epoch 9/50
# 6/6 [==============================] - 3s 457ms/step - loss: 0.4864 - categorical_accuracy: 0.9298 - val_loss: 0.4511 - val_categorical_accuracy: 0.9914
# Epoch 10/50
# 6/6 [==============================] - 2s 401ms/step - loss: 0.4563 - categorical_accuracy: 0.9815 - val_loss: 0.4494 - val_categorical_accuracy: 0.9138
# Epoch 11/50
# 6/6 [==============================] - 3s 444ms/step - loss: 0.4263 - categorical_accuracy: 0.9612 - val_loss: 0.3941 - val_categorical_accuracy: 0.9914
# Epoch 12/50
# 6/6 [==============================] - 2s 394ms/step - loss: 0.3935 - categorical_accuracy: 0.9834 - val_loss: 0.3695 - val_categorical_accuracy: 1.0000
# Epoch 13/50
# 6/6 [==============================] - 2s 400ms/step - loss: 0.3652 - categorical_accuracy: 0.9815 - val_loss: 0.3374 - val_categorical_accuracy: 0.9828
# Epoch 14/50
# 6/6 [==============================] - 2s 410ms/step - loss: 0.3340 - categorical_accuracy: 0.9908 - val_loss: 0.3174 - val_categorical_accuracy: 0.9828
# Epoch 15/50
# 6/6 [==============================] - 2s 390ms/step - loss: 0.3147 - categorical_accuracy: 0.9760 - val_loss: 0.2806 - val_categorical_accuracy: 0.9914
# Epoch 16/50
# 6/6 [==============================] - 2s 388ms/step - loss: 0.2748 - categorical_accuracy: 0.9852 - val_loss: 0.2434 - val_categorical_accuracy: 0.9914
# Epoch 17/50
# 6/6 [==============================] - 2s 386ms/step - loss: 0.2408 - categorical_accuracy: 0.9889 - val_loss: 0.2152 - val_categorical_accuracy: 0.9914
# Epoch 18/50
# 6/6 [==============================] - 2s 433ms/step - loss: 0.2125 - categorical_accuracy: 0.9889 - val_loss: 0.1969 - val_categorical_accuracy: 0.9828
# Epoch 19/50
# 6/6 [==============================] - 2s 391ms/step - loss: 0.1960 - categorical_accuracy: 0.9852 - val_loss: 0.1687 - val_categorical_accuracy: 0.9914
# Epoch 20/50
# 6/6 [==============================] - 3s 442ms/step - loss: 0.1680 - categorical_accuracy: 0.9889 - val_loss: 0.1463 - val_categorical_accuracy: 0.9914
# Epoch 21/50
# 6/6 [==============================] - 2s 423ms/step - loss: 0.1482 - categorical_accuracy: 0.9926 - val_loss: 0.1292 - val_categorical_accuracy: 0.9914
# Epoch 22/50
# 6/6 [==============================] - 2s 372ms/step - loss: 0.1344 - categorical_accuracy: 0.9945 - val_loss: 0.1147 - val_categorical_accuracy: 0.9914
# Epoch 23/50
# 6/6 [==============================] - 2s 427ms/step - loss: 0.1175 - categorical_accuracy: 0.9945 - val_loss: 0.1015 - val_categorical_accuracy: 0.9914
# Epoch 24/50
# 6/6 [==============================] - 2s 374ms/step - loss: 0.1054 - categorical_accuracy: 0.9945 - val_loss: 0.0906 - val_categorical_accuracy: 0.9914
# Epoch 25/50
# 6/6 [==============================] - 3s 441ms/step - loss: 0.0961 - categorical_accuracy: 0.9945 - val_loss: 0.0813 - val_categorical_accuracy: 0.9914
# Epoch 26/50
# 6/6 [==============================] - 2s 431ms/step - loss: 0.0884 - categorical_accuracy: 0.9963 - val_loss: 0.0751 - val_categorical_accuracy: 1.0000
# Epoch 27/50
# 6/6 [==============================] - 2s 424ms/step - loss: 0.0795 - categorical_accuracy: 0.9963 - val_loss: 0.0674 - val_categorical_accuracy: 0.9914
# Epoch 28/50
# 6/6 [==============================] - 2s 424ms/step - loss: 0.0722 - categorical_accuracy: 0.9982 - val_loss: 0.0618 - val_categorical_accuracy: 0.9914
# Epoch 29/50
# 6/6 [==============================] - 2s 424ms/step - loss: 0.0687 - categorical_accuracy: 0.9963 - val_loss: 0.0557 - val_categorical_accuracy: 1.0000
# Epoch 30/50
# 6/6 [==============================] - 2s 381ms/step - loss: 0.0607 - categorical_accuracy: 0.9963 - val_loss: 0.0514 - val_categorical_accuracy: 1.0000
# Epoch 31/50
# 6/6 [==============================] - 2s 394ms/step - loss: 0.0555 - categorical_accuracy: 0.9982 - val_loss: 0.0494 - val_categorical_accuracy: 0.9914
# Epoch 32/50
# 6/6 [==============================] - 2s 428ms/step - loss: 0.0543 - categorical_accuracy: 0.9945 - val_loss: 0.0441 - val_categorical_accuracy: 1.0000
# Epoch 33/50
# 6/6 [==============================] - 3s 452ms/step - loss: 0.0493 - categorical_accuracy: 0.9945 - val_loss: 0.0413 - val_categorical_accuracy: 1.0000
# Epoch 34/50
# 6/6 [==============================] - 2s 427ms/step - loss: 0.0448 - categorical_accuracy: 0.9963 - val_loss: 0.0427 - val_categorical_accuracy: 0.9914
# Epoch 35/50
# 6/6 [==============================] - 2s 408ms/step - loss: 0.0439 - categorical_accuracy: 0.9945 - val_loss: 0.0370 - val_categorical_accuracy: 1.0000
# Epoch 36/50
# 6/6 [==============================] - 3s 457ms/step - loss: 0.0396 - categorical_accuracy: 0.9982 - val_loss: 0.0399 - val_categorical_accuracy: 0.9914
# Epoch 37/50
# 6/6 [==============================] - 2s 393ms/step - loss: 0.0390 - categorical_accuracy: 0.9945 - val_loss: 0.0321 - val_categorical_accuracy: 1.0000
# Epoch 38/50
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0342 - categorical_accuracy: 0.9982 - val_loss: 0.0328 - val_categorical_accuracy: 0.9914
# Epoch 39/50
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0331 - categorical_accuracy: 0.9982 - val_loss: 0.0288 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 6/6 [==============================] - 2s 392ms/step - loss: 0.0307 - categorical_accuracy: 0.9982 - val_loss: 0.0296 - val_categorical_accuracy: 0.9914
# Epoch 41/50
# 6/6 [==============================] - 3s 443ms/step - loss: 0.0302 - categorical_accuracy: 0.9982 - val_loss: 0.0268 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 6/6 [==============================] - 3s 452ms/step - loss: 0.0281 - categorical_accuracy: 1.0000 - val_loss: 0.0268 - val_categorical_accuracy: 0.9914
# Epoch 43/50
# 6/6 [==============================] - 2s 389ms/step - loss: 0.0278 - categorical_accuracy: 1.0000 - val_loss: 0.0237 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 6/6 [==============================] - 2s 392ms/step - loss: 0.0262 - categorical_accuracy: 0.9982 - val_loss: 0.0227 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0238 - categorical_accuracy: 1.0000 - val_loss: 0.0224 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 6/6 [==============================] - 2s 386ms/step - loss: 0.0232 - categorical_accuracy: 1.0000 - val_loss: 0.0208 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 6/6 [==============================] - 2s 403ms/step - loss: 0.0217 - categorical_accuracy: 1.0000 - val_loss: 0.0207 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 6/6 [==============================] - 3s 441ms/step - loss: 0.0207 - categorical_accuracy: 1.0000 - val_loss: 0.0194 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 6/6 [==============================] - 2s 384ms/step - loss: 0.0198 - categorical_accuracy: 1.0000 - val_loss: 0.0195 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 6/6 [==============================] - 2s 397ms/step - loss: 0.0194 - categorical_accuracy: 1.0000 - val_loss: 0.0179 - val_categorical_accuracy: 1.0000
# ###### Total Time Taken:  3 Minutes ######

# %%
acc = hist.history['categorical_accuracy']
val_acc = hist.history['val_categorical_accuracy']
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, '-', label = 'Training Categorical Accuracy')
plt.plot(epochs, val_acc, ':', label = 'Validation Categorical Accuracy')
plt.title('Training and Validation Categorical Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc = 'lower right')
plt.plot()
plt.figure()
plt.plot(epochs, loss, '-', label = 'Training Loss')
plt.plot(epochs, val_loss, ':', label = 'Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc = 'lower right')
plt.plot()
# Out:
# []

# %%
y_predicted = model.predict(x_valid)
mat = confusion_matrix(y_valid.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = data.target_names, yticklabels = data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 3s 338ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %%
y_predicted = model.predict(x_test)
mat = confusion_matrix(y_test.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = data.target_names, yticklabels = data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 1s 376ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %% [markdown]
# ## Use transfer learning with ResNet50 and VGGFace2 weights
#
# Inicializada con pesos de ImageNet, ResNet50 logra una precisión de alrededor del 90 % en el reconocimiento  en el conjunto de datos de LFW. Pero los pesos de ImageNet se generaron entrenando la red con imágenes de cientos de objetos diferentes. Estos pesos no están optimizados para extraer características de las caras.
#
# keras-vggface es un paquete de Python que modela CNN preentrenadas para reconocer las caras de personas famosas. Estas CNN (y sus pesos) están encapsuladas en una clase denominada VGGFace. Se cargan las capas de cuello de botella de la versión ResNet50 de VGGFace junto con los pesos a los que se llegó cuando se entrenó con más de 3 millones de imágenes en el conjunto de datos VGGFace2 y se usa el transfer learning para entrenar la red resultante en el conjunto de datos LFW. Como antes, se comienza por cargar VGGFace sin las capas de clasificación y congelando las capas de cuello de botella.
#
# Una capa de cuello de botella, en inglés bottleneck layer, es una capa que contiene pocos nodos en comparación con las capas anteriores. Se puede utilizar para obtener una representación de la entrada con dimensionalidad reducida. Un ejemplo de esto es el uso de codificadores automáticos con capas de cuello de botella para la reducción de dimensionalidad no lineal.
# Con ello se reduce el número de parámetros y las multiplicaciones de matrices. La idea es hacer que los bloques residuales sean lo más pequeños posible para aumentar la profundidad y tener menos parámetros.

# %%
import site; print(site.getsitepackages())
# Out:
# ['/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/lib/python3.10/dist-packages']

# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# !pip install keras_applications --no-deps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/rcmalli/keras-vggface.git
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-swzpl9gq
#   Running command git clone --filter=blob:none --quiet https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-swzpl9gq
#   Resolved https://github.com/rcmalli/keras-vggface.git to commit bee35376e76e35d00aeec503f2f242611a97b38a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (1.22.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (1.10.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (3.8.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (8.4.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (2.12.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_applications in /usr/local/lib/python3.10/dist-packages (1.0.8)

# %%
# For WINDOWS
# ==========
# filename = "C:/Users/lfsanchez/Anaconda3/Lib/site-packages/keras_vggface/models.py"
# f=open(filename)
# text = f.read()
# f.close()
# f=open(filename, "w+")
# f.write(text.replace('keras.engine.topology', 'tensorflow.keras.utils'))
# f.close()

# %%
# For UNIX
# ==========
# filename = "/usr/local/lib/python3.8/dist-packages/keras_vggface/models.py"
# text = open(filename).read()
# open(filename, "w+").write(text.replace('keras.engine.topology', 'tensorflow.keras.utils'))

# %%
new_x_faces = []
for img in x_faces:
  norm_image = cv2.normalize(img, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
  norm_image = norm_image.astype(np.uint8)
  new_x_faces.append(norm_image)

new_x_faces = np.array(new_x_faces)
new_x_faces.shape
# Out:
# (774, 190, 190, 3)

# %%
####### Train and test splitting of data #######

from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

face_labels = to_categorical(y_faces)

# In the first step we will split the data in training and remaining dataset
x_train, x_rem, y_train, y_rem = train_test_split(new_x_faces, face_labels, train_size = 0.7, stratify = face_labels, random_state = 0)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# Define valid_size=0.5 (that is 50% of remaining data)
x_valid, x_test, y_valid, y_test = train_test_split(x_rem, y_rem, test_size = 0.5, stratify = y_rem, random_state = 0)

print("Train: ", x_train.shape)
print("Validation: ", x_valid.shape)
print("Test: ", x_test.shape)
# Out:
# Train:  (541, 190, 190, 3)
# Validation:  (116, 190, 190, 3)
# Test:  (117, 190, 190, 3)

# %%
from keras_vggface.vggface import VGGFace

base_model = VGGFace(model = 'resnet50', include_top = False)
base_model.trainable = False

# %% [markdown]
# Se añaden las capas de clasificación al modelo de base y se incluye una capa de reajuste para redimensionar las imagenes puestas como entrada a la red a 224x224

# %%
model2 = Sequential()
model2.add(Resizing(224, 224))
model2.add(base_model)
model2.add(Flatten())
model2.add(Dense(1024, activation = 'relu'))
model2.add(Dense(class_count, activation = 'sigmoid'))
model2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['categorical_accuracy'])

# %%
import time

start_time = time.time()
hist = model2.fit(x_train, y_train, validation_data = (x_valid, y_valid), batch_size = 100, epochs = 10)
end_time = time.time()

print("###### Total Time Taken: ", round((end_time - start_time)/60), 'Minutes ######')
# Out:
# Epoch 1/10
# 6/6 [==============================] - 14s 1s/step - loss: 0.9775 - categorical_accuracy: 0.8983 - val_loss: 7.8684e-12 - val_categorical_accuracy: 1.0000
# Epoch 2/10
# 6/6 [==============================] - 2s 368ms/step - loss: 1.8320e-06 - categorical_accuracy: 1.0000 - val_loss: 2.5830e-18 - val_categorical_accuracy: 1.0000
# Epoch 3/10
# 6/6 [==============================] - 2s 314ms/step - loss: 4.3827e-07 - categorical_accuracy: 1.0000 - val_loss: 1.0760e-21 - val_categorical_accuracy: 1.0000
# Epoch 4/10
# 6/6 [==============================] - 2s 370ms/step - loss: 7.6452e-08 - categorical_accuracy: 1.0000 - val_loss: 1.7440e-23 - val_categorical_accuracy: 1.0000
# Epoch 5/10
# 6/6 [==============================] - 2s 331ms/step - loss: 4.7429e-08 - categorical_accuracy: 1.0000 - val_loss: 1.9272e-24 - val_categorical_accuracy: 1.0000
# Epoch 6/10
# 6/6 [==============================] - 2s 347ms/step - loss: 3.0290e-08 - categorical_accuracy: 1.0000 - val_loss: 5.6768e-25 - val_categorical_accuracy: 1.0000
# Epoch 7/10
# 6/6 [==============================] - 2s 397ms/step - loss: 2.3440e-08 - categorical_accuracy: 1.0000 - val_loss: 2.8524e-25 - val_categorical_accuracy: 1.0000
# Epoch 8/10
# 6/6 [==============================] - 2s 325ms/step - loss: 2.0289e-08 - categorical_accuracy: 1.0000 - val_loss: 1.9327e-25 - val_categorical_accuracy: 1.0000
# Epoch 9/10
# 6/6 [==============================] - 2s 378ms/step - loss: 1.8227e-08 - categorical_accuracy: 1.0000 - val_loss: 1.5530e-25 - val_categorical_accuracy: 1.0000
# Epoch 10/10
# 6/6 [==============================] - 2s 313ms/step - loss: 1.7964e-08 - categorical_accuracy: 1.0000 - val_loss: 1.3735e-25 - val_categorical_accuracy: 1.0000
# ###### Total Time Taken:  1 Minutes ######

# %% [markdown]
# La función relu ayuda a prevenir el crecimiento exponencial en la computación requerida para operar la red neuronal. Si la CNN aumenta en tamaño, el coste computacional de agregar ReLU adicionales aumenta linealmente.
# La función softmax se utiliza como función de activación en la capa de salida de los modelos de redes neuronales que predicen una distribución de probabilidad multinomial

# %%
acc = hist.history['categorical_accuracy']
val_acc = hist.history['val_categorical_accuracy']
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, '-', label = 'Training Categorical Accuracy')
plt.plot(epochs, val_acc, ':', label = 'Validation Categorical Accuracy')
plt.title('Training and Validation Categorical Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc = 'lower right')
plt.plot()
plt.figure()
plt.plot(epochs, loss, '-', label = 'Training Loss')
plt.plot(epochs, val_loss, ':', label = 'Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc = 'lower right')
plt.plot()
# Out:
# []

# %%
y_predicted = model2.predict(x_valid)
mat = confusion_matrix(y_valid.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = data.target_names, yticklabels = data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 2s 180ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %%
y_predicted = model2.predict(x_test)
mat = confusion_matrix(y_test.argmax(axis=1), y_predicted.argmax(axis=1))
 
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels = data.target_names, yticklabels = data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 1s 192ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %% [markdown]
# ## Testing data
#
# Probar y testear el modelo con datos que no han pasado por el mismo, es decir, caras completamente nuevas para observar en datos no vistos por el modelo para su entrenamiento.

# %%
# For GOOGLE COLAB
# ==========
test_data_dir = "/content/drive/MyDrive/Colab Notebooks/scikit_learn_data_test"

# %%
# For OS
# ==========

"""
import os
d = os.path.dirname(os.getcwd())
data_zip_dir = os.path.join(d, "data/test/scikit_learn_data_test.zip")
import zipfile
with zipfile.ZipFile(data_zip_dir, 'r') as zip_ref:
   zip_ref.extractall(os.path.join(d, "data/test"))

data_dir = os.path.join(d, "data/test/scikit_learn_data_test")
"""
# Out:
# '\nimport os\nd = os.path.dirname(os.getcwd())\ndata_zip_dir = os.path.join(d, "data/test/scikit_learn_data_test.zip")\nimport zipfile\nwith zipfile.ZipFile(data_zip_dir, \'r\') as zip_ref:\n   zip_ref.extractall(os.path.join(d, "data/test"))\n\ndata_dir = os.path.join(d, "data/test/scikit_learn_data_test")\n'

# %%
#data = fetch_lfw_people(data_home = data_dir, resize=1.0, color=True)
test_data = fetch_lfw_people(data_home = test_data_dir, min_faces_per_person = 100, resize = 1.0, slice_ = (slice(30, 220), slice(30, 220)), color = True, funneled = True)

class_count = len(data.target_names)

# %%
from collections import Counter
counts = Counter(test_data.target)
names = {}

for key in counts.keys():
    names[test_data.target_names[key]] = counts[key]

df = pd.DataFrame.from_dict(names, orient = 'index')
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
# %matplotlib inline
import seaborn as sns
sns.set()

fig, ax = plt.subplots(3, 6, figsize=(18, 10))

for i, axi in enumerate(ax.flat):
    axi.imshow(test_data.images[i], cmap = plt.cm.gray_r, vmin = 0, vmax = 16)
    axi.set(xticks = [], yticks = [], xlabel = test_data.target_names[test_data.target[i]])

# %%
mask = np.zeros(test_data.target.shape, dtype = np.bool_)

for target in np.unique(test_data.target):
    mask[np.where(test_data.target == target)[0][:100]] = 1

x_faces_test = test_data.data[mask]
y_faces_test = test_data.target[mask]
x_faces_test = np.reshape(x_faces_test, (x_faces_test.shape[0], test_data.images.shape[1], test_data.images.shape[2], test_data.images.shape[3]))

face_images_test = preprocess_input(np.array(x_faces_test))
face_labels_test = to_categorical(y_faces_test)

# %%
# In the first step we will split the data in training and remaining dataset
x_test1, x_test2, y_test1, y_test2 = train_test_split(face_images_test, face_labels_test, train_size = 0.5, stratify = face_labels_test, random_state = 0)

# %%
y_predicted = model.predict(x_test1)
mat = confusion_matrix(y_test1.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = test_data.target_names, yticklabels = test_data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 1s 267ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %%
y_predicted = model.predict(x_test2)
mat = confusion_matrix(y_test1.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = test_data.target_names, yticklabels = test_data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 0s 92ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %%
new_x_faces_test = []
for img in x_faces_test:
  norm_image = cv2.normalize(img, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
  norm_image = norm_image.astype(np.uint8)
  new_x_faces_test.append(norm_image)

new_x_faces_test = np.array(new_x_faces_test)
new_x_faces_test.shape
# Out:
# (200, 190, 190, 3)

# %%
####### Test splitting of data #######

face_labels = to_categorical(y_faces_test)

# In the first step we will split the data in training and remaining dataset
x_test3, x_test4, y_test3, y_test4 = train_test_split(new_x_faces_test, face_labels, train_size = 0.5, stratify = face_labels, random_state = 0)

print("Test 1: ", x_test3.shape)
print("Test 2: ", x_test4.shape)
# Out:
# Test 1:  (100, 190, 190, 3)
# Test 2:  (100, 190, 190, 3)

# %%
y_predicted = model2.predict(x_test3)
mat = confusion_matrix(y_test3.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = test_data.target_names, yticklabels = test_data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 0s 131ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %%
y_predicted = model2.predict(x_test4)
mat = confusion_matrix(y_test4.argmax(axis = 1), y_predicted.argmax(axis = 1))
 
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False, cmap = 'Blues',
            xticklabels = test_data.target_names, yticklabels = test_data.target_names)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# 4/4 [==============================] - 0s 77ms/step
# Text(109.44999999999997, 0.5, 'Actual label')

# %%
import keras.utils as image

# For GOOGLE COLAB
test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00529.jpg')

# For OS
"""
d = os.path.dirname(os.getcwd())
data_zip_dir = os.path.join(d, "data/test/scikit_learn_data_test.zip")

with zipfile.ZipFile(data_zip_dir, 'r') as zip_ref:
    zip_ref.extractall(os.path.join(d, "data/test"))

test_image_dir = os.path.join(d, "data/test/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_0005.jpg")
test_image = image.load_img(test_image_dir)
"""

plt.xticks([])
plt.yticks([])
plt.imshow(test_image)

import base64
import io
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

image_1 = "[Log] data:image/jpeg;base64,..."
image_1 = image_1.split(",")[1]
imgdata = base64.b64decode(image_1)
img = Image.open(io.BytesIO(imgdata))

test_image= cv2.flip(cv2.cvtColor(np.array(img)[:, :, ::-1], cv2.COLOR_RGB2BGR), 1)
test_image = Image.fromarray(test_image)

width, height = test_image.size
left = (width - 250) / 2
top = (height - 250) / 2
right = (width + 250) / 2
bottom = (height + 250) / 2

test_image = test_image.crop((left, top, right, bottom))
test_image = np.array(test_image)

plt.xticks([])
plt.yticks([])
plt.imshow(test_image)

# %%
x = image.img_to_array(test_image)
x = np.expand_dims(x, axis=0)

y = model2.predict(x)[0]
for i in range(len(y)):
    print(data.target_names[i] + ': ' + str(y[i]))
# Out:
# 1/1 [==============================] - 2s 2s/step
# People: 0.99999917
# Sergio Cuenca: 1.01715626e-13

# %%
# For GOOGLE COLAB
test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00626.jpg')

# For OS
"""
test_image_dir = os.path.join(d, "data/test/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00059.jpg")
test_image = image.load_img(test_image_dir)
"""

plt.xticks([])
plt.yticks([])
plt.imshow(test_image)

# %%
x = image.img_to_array(test_image)
x = np.expand_dims(x, axis=0)

y = model2.predict(x)[0]
for i in range(len(y)):
    print(data.target_names[i] + ': ' + str(y[i]))
# Out:
# 1/1 [==============================] - 0s 32ms/step
# People: 2.41296e-25
# Sergio Cuenca: 1.0

# %% [markdown]
# ## Save model
# Guardar y exportar el modelo en un archivo para poder utilizarlo más tarde.

# %%
from keras.models import load_model

# For GOOGLE COLAB
model_dir = "/content/drive/MyDrive/Colab Notebooks/cnn_model_4.h5"

# For OS
"""
d = os.path.dirname(os.getcwd())
model_dir = os.path.join(d, "models/cnn_model_4.h5")
"""

# Guarda el modelo en un archivo
model.save(model_dir)

# %%
imported_model = load_model(model_dir)

# For GOOGLE COLAB
test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00059.jpg')

# For OS
"""
test_image_dir = os.path.join(d, "data/test/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00059.jpg")
test_image = image.load_img(test_image_dir)
"""

x = image.img_to_array(test_image)
x = np.expand_dims(x, axis=0)
y = imported_model.predict(x)[0]

for i in range(len(y)):
    print(data.target_names[i] + ': ' + str(y[i]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-d2dfd96dadd1> in <cell line: 4>()
#       2
#       3 # For GOOGLE COLAB
# ----> 4 test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00059.jpg')
#       5
#       6 # For OS
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/scikit_learn_data_test/lfw_home/lfw_funneled/Sergio_Cuenca/Sergio_Cuenca_00059.jpg'
